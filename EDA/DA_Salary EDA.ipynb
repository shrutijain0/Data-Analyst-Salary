# %% [markdown]
# # ***EDA ON DATA ANALYST'S DATA***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Cleaned DS data.csv')
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded  ... Title_Simplified   Level Min_salary  \
# 0    201 to 500 employees     1961  ...          analyst      na       37.0
# 1        10000+ employees     1893  ...     data analyst      na       37.0
# 2  1001 to 5000 employees     2003  ...     data analyst  Senior       37.0
# 3    201 to 500 employees     2002  ...          analyst      na       37.0
# 4   501 to 1000 employees     2009  ...     data analyst      na       37.0
#
#   Max_salary description job_location  age num_comp  avg_salary  \
# 0         66        7057           NY   59        0        51.5
# 1         66        4702           NY  127        0        51.5
# 2         66        4688           NY   17        1        51.5
# 3         66        5249           NY   18        0        51.5
# 4         66        3376           NY   11        1        51.5
#
#                             company_txt
# 0           Vera Institute of Justice\n
# 1  Visiting Nurse Service of New York\n
# 2                         Squarespace\n
# 3                            Celerity\n
# 4                             FanDuel\n
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Title_Simplified', 'Level', 'Min_salary', 'Max_salary',
#        'description', 'job_location', 'age', 'num_comp', 'avg_salary',
#        'company_txt'],
#       dtype='object')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.describe()
# Out:
#             Rating      Founded   Min_salary   Max_salary   description  \
# count  2253.000000  2253.000000  2252.000000  2253.000000   2253.000000
# mean      3.160630  1398.522858    54.266874    89.939636   3119.279627
# std       1.665228   901.929251    19.575375    29.368984   1858.355531
# min      -1.000000    -1.000000    24.000000     1.000000      5.000000
# 25%       3.100000    -1.000000    41.000000    70.000000   1761.000000
# 50%       3.600000  1979.000000    50.000000    87.000000   2880.000000
# 75%       4.000000  2002.000000    64.000000   104.000000   4117.000000
# max       5.000000  2019.000000   113.000000   190.000000  18664.000000
#
#                age     num_comp   avg_salary
# count  2253.000000  2253.000000  2252.000000
# mean     29.146915     0.608966    72.123002
# std      44.647864     1.148112    23.600734
# min      -1.000000     0.000000    33.500000
# 25%      -1.000000     0.000000    58.000000
# 50%      16.000000     0.000000    69.000000
# 75%      33.000000     0.000000    80.500000
# max     338.000000     4.000000   150.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
#  15  Title_Simplified   2253 non-null   object
#  16  Level              2253 non-null   object
#  17  Min_salary         2252 non-null   float64
#  18  Max_salary         2253 non-null   int64
#  19  description        2253 non-null   int64
#  20  job_location       2253 non-null   object
#  21  age                2253 non-null   int64
#  22  num_comp           2253 non-null   int64
#  23  avg_salary         2252 non-null   float64
#  24  company_txt        2252 non-null   object
# dtypes: float64(3), int64(5), object(17)
# memory usage: 440.2+ KB

# %%
df.isnull().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# Title_Simplified     0
# Level                0
# Min_salary           1
# Max_salary           0
# description          0
# job_location         0
# age                  0
# num_comp             0
# avg_salary           1
# company_txt          1
# dtype: int64

# %%
df.corr()
# Out:
#                Rating   Founded  Min_salary  Max_salary  description  \
# Rating       1.000000  0.500465   -0.007836    0.011129    -0.018874
# Founded      0.500465  1.000000   -0.005453    0.000207     0.110329
# Min_salary  -0.007836 -0.005453    1.000000    0.858547    -0.035332
# Max_salary   0.011129  0.000207    0.858547    1.000000    -0.029650
# description -0.018874  0.110329   -0.035332   -0.029650     1.000000
# age          0.184280  0.394133   -0.066443   -0.077330     0.255156
# num_comp     0.166255  0.328553    0.000867    0.003724     0.109954
# avg_salary   0.004301 -0.001574    0.947941    0.977130    -0.033643
#
#                   age  num_comp  avg_salary
# Rating       0.184280  0.166255    0.004301
# Founded      0.394133  0.328553   -0.001574
# Min_salary  -0.066443  0.000867    0.947941
# Max_salary  -0.077330  0.003724    0.977130
# description  0.255156  0.109954   -0.033643
# age          1.000000  0.297702   -0.075872
# num_comp     0.297702  1.000000    0.002233
# avg_salary  -0.075872  0.002233    1.000000

# %% [markdown]
# ### ***Visualization of the data***

# %%
df.hist(figsize=(20,10))
plt.show()

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                Rating   Founded  Min_salary  Max_salary  description  \
# Rating       1.000000  0.500465   -0.007836    0.011129    -0.018874
# Founded      0.500465  1.000000   -0.005453    0.000207     0.110329
# Min_salary  -0.007836 -0.005453    1.000000    0.858547    -0.035332
# Max_salary   0.011129  0.000207    0.858547    1.000000    -0.029650
# description -0.018874  0.110329   -0.035332   -0.029650     1.000000
# age          0.184280  0.394133   -0.066443   -0.077330     0.255156
# num_comp     0.166255  0.328553    0.000867    0.003724     0.109954
# avg_salary   0.004301 -0.001574    0.947941    0.977130    -0.033643
#
#                   age  num_comp  avg_salary
# Rating       0.184280  0.166255    0.004301
# Founded      0.394133  0.328553   -0.001574
# Min_salary  -0.066443  0.000867    0.947941
# Max_salary  -0.077330  0.003724    0.977130
# description  0.255156  0.109954   -0.033643
# age          1.000000  0.297702   -0.075872
# num_comp     0.297702  1.000000    0.002233
# avg_salary  -0.075872  0.002233    1.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Title_Simplified', 'Level', 'Min_salary', 'Max_salary',
#        'description', 'job_location', 'age', 'num_comp', 'avg_salary',
#        'company_txt'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Title_Simplified'],order = df['Title_Simplified'].value_counts().index,palette='RdPu')
# Out:
# <AxesSubplot:xlabel='Title_Simplified', ylabel='count'>

# %% [markdown]
# ### ***-Analyst is most number job posted on glassdoor (analyst is where they have not defined any specific analytics process to be taken by the people)***

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Location'],order = df['Location'].value_counts()[:20].index,palette='flare')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***- New York is leading in term of data analyst jobs on glassdoor***
# ### ***- Plano is least recruting in term of data analyst jobs on glassdoor***

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Type of ownership'],order = df['Type of ownership'].value_counts()[:20].index,palette='autumn_r')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***- Private are the one who are hiring most analyst***

# %%
plt.figure(figsize=(10,5))
sns.countplot(y=df['Sector'],order = df['Sector'].value_counts()[:20].index,palette='RdBu')
plt.xticks(rotation=80)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***- IT and Business Service is sector who is hiring most number of analyst***
# ### ***- Real Estate is sector who hire least number of analyst***

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Level'],order = df['Level'].value_counts().index,palette='Set3')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***- Most of the job description doesnt show the seniority so NA is highest level and Senior is second most in seniority level***

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Easy Apply'],order = df['Easy Apply'].value_counts().index,palette='RdPu')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***- Most of the job searcher has not used Easy Apply function to apply (or) most of recruiter has not given easy apply function***

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Revenue'],order = df['Revenue'].value_counts().index,palette='CMRmap_r')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Industry'],order = df['Industry'].value_counts()[:20].index,palette='RdPu')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['avg_salary'] = (df['Min_salary']+df['Max_salary'])/2

# %%
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-3], axis = 1)

# %%
df.to_csv('Cleaned DS data.csv')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['company_txt'],order = df['company_txt'].value_counts()[:20].index,palette='RdPu')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Title_Simplified', 'Level', 'Min_salary', 'Max_salary',
#        'description', 'job_location', 'age', 'num_comp', 'avg_salary',
#        'company_txt'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'Title_Simplified', values = 'avg_salary')
# Out:
#                    avg_salary
# Title_Simplified
# analyst             71.481928
# business analyst    68.000000
# data analyst        73.322361
# data scientist      70.785714
# product analyst     61.750000
# reporting analyst   73.097826

# %%
pd.pivot_table(df, index = ['Title_Simplified','Level'], values = 'avg_salary')
# Out:
#                                avg_salary
# Title_Simplified  Level
# analyst           Entry Level   52.400000
#                   JR            65.051724
#                   Senior        71.058333
#                   na            71.786893
# business analyst  Senior        68.875000
#                   na            67.708333
# data analyst      Entry Level   69.500000
#                   JR            62.034091
#                   Senior        75.900888
#                   na            72.577309
# data scientist    Senior        84.500000
#                   na            63.166667
# product analyst   na            61.750000
# reporting analyst Senior        93.500000
#                   na            72.170455

# %%
pd.pivot_table(df, index = ['job_location','Title_Simplified'], values = 'avg_salary', aggfunc = 'count').sort_values('job_location', ascending = False)
# Out:
#                                 avg_salary
# job_location Title_Simplified
#  WA          data analyst               23
#              analyst                    30
#  VA          data analyst               17
#              business analyst            3
#              analyst                    28
# ...                                    ...
#  Arapahoe    analyst                     3
#  AZ          data analyst               39
#              business analyst            4
#              reporting analyst           2
#              analyst                    52
#
# [70 rows x 1 columns]

# %%
pd.pivot_table(df, index = 'company_txt', values = 'avg_salary')
# Out:
#                                     avg_salary
# company_txt
# 1                                         41.5
# 1199SEIU Funds\n                          63.5
# 1872 Consulting\n                         59.0
# 2000 east westmoreland st llc             59.5
# 212 Factors                               75.5
# ...                                        ...
# smlogics                                  51.0
# softsnippets                              38.5
# thredUP\n                                138.5
# xentity corporation\n                     70.0
# zz-Tarzana Treatment Centers, Inc.        73.0
#
# [1503 rows x 1 columns]

# %%
pd.pivot_table(df, index = 'job_location', values = 'avg_salary')
# Out:
#               avg_salary
# job_location
#  AZ            70.788660
#  Arapahoe      72.250000
#  CA            88.432109
#  CO            73.619318
#  DE            59.727273
#  FL            51.851852
#  GA            44.000000
#  IL            78.310976
#  IN            47.500000
#  KS            51.500000
#  NC            68.111111
#  NJ            73.000000
#  NY            71.411594
#  OH            45.200000
#  PA            61.728070
#  SC            68.333333
#  TX            58.751269
#  UT            37.530303
#  VA            65.187500
#  WA            64.754717

# %%
pd.pivot_table(df, index = 'Revenue', values = 'avg_salary')
# Out:
#                                   avg_salary
# Revenue
# $1 to $2 billion (USD)             70.327586
# $1 to $5 million (USD)             75.941441
# $10 to $25 million (USD)           70.553030
# $10+ billion (USD)                 70.457672
# $100 to $500 million (USD)         71.830275
# $2 to $5 billion (USD)             71.794574
# $25 to $50 million (USD)           74.651376
# $5 to $10 billion (USD)            73.732143
# $5 to $10 million (USD)            70.451389
# $50 to $100 million (USD)          68.834171
# $500 million to $1 billion (USD)   69.829114
# -1                                 73.469325
# Less than $1 million (USD)         70.903226
# Unknown / Non-Applicable           73.496748

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\milin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\milin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 1000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## ***THANK YOU!!!***
